# %% [markdown]
# # 6010405513

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1

# %%
medals = pd.read_csv("olympic.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-60ee3ffdfcb4> in <module>
# ----> 1 medals = pd.read_csv("olympic.csv")
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'olympic.csv' does not exist: b'olympic.csv'

# %%
medals.columns = ["country","Game", "Gold", "Silver", "Bronze", "Game", "Gold", "Silver", "Bronze"]

# %% [markdown]
# ## 2

# %%
DF = pd.read_csv("drinks.csv")

# %%
DF = DF.fillna('NA')

# %%
DF.head(20)
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 1             Albania             89              132             54
# 2             Algeria             25                0             14
# 3             Andorra            245              138            312
# 4              Angola            217               57             45
# 5   Antigua & Barbuda            102              128             45
# 6           Argentina            193               25            221
# 7             Armenia             21              179             11
# 8           Australia            261               72            212
# 9             Austria            279               75            191
# 10         Azerbaijan             21               46              5
# 11            Bahamas            122              176             51
# 12            Bahrain             42               63              7
# 13         Bangladesh              0                0              0
# 14           Barbados            143              173             36
# 15            Belarus            142              373             42
# 16            Belgium            295               84            212
# 17             Belize            263              114              8
# 18              Benin             34                4             13
# 19             Bhutan             23                0              0
#
#     total_litres_of_pure_alcohol continent
# 0                            0.0        AS
# 1                            4.9        EU
# 2                            0.7        AF
# 3                           12.4        EU
# 4                            5.9        AF
# 5                            4.9        NA
# 6                            8.3        SA
# 7                            3.8        EU
# 8                           10.4        OC
# 9                            9.7        EU
# 10                           1.3        EU
# 11                           6.3        NA
# 12                           2.0        AS
# 13                           0.0        AS
# 14                           6.3        NA
# 15                          14.4        EU
# 16                          10.5        EU
# 17                           6.8        NA
# 18                           1.1        AF
# 19                           0.4        AS

# %% [markdown]
# ## 3

# %%
DF.isnull().sum()
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# continent                       0
# dtype: int64

# %% [markdown]
# ## 4

# %%
medals['country'] = medals['country'].str.extract("(.+)\s\(")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-31c4a45bf214> in <module>
# ----> 1 medals['country'] = medals['country'].str.extract("(.+)\s\(")
#
# NameError: name 'medals' is not defined

# %%
medals.loc[~medals['country'].isin(DF['country']) == True, ['country']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-743209f920f5> in <module>
# ----> 1 medals.loc[~medals['country'].isin(DF['country']) == True, ['country']]
#
# NameError: name 'medals' is not defined

# %% [markdown]
# ## 5

# %%
DF.loc[~DF['country'].isin(medals['country']) == True, ['country']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-22f532a0b960> in <module>
# ----> 1 DF.loc[~DF['country'].isin(medals['country']) == True, ['country']]
#
# NameError: name 'medals' is not defined

# %% [markdown]
# ## 6

# %%
medals['continent'] = medals.merge(DF, on='country', how='left').continent
medals

# %% [markdown]
# ## 7

# %%
medals.loc[medals.continent.isnull() == True, ['country']]
# Out:
#                               country
# 4                         Australasia
# 13                            Bermuda
# 14                            Bohemia
# 17                British West Indies
# 26                        Ivory Coast
# 31                     Czechoslovakia
# 45             United Team of Germany
# 46                       East Germany
# 47                       West Germany
# 49                      Great Britain
# 55                          Hong Kong
# 75                      Liechtenstein
# 89               Netherlands Antilles
# 101                       Puerto Rico
# 104                            Russia
# 105                    Russian Empire
# 106                      Soviet Union
# 107                      Unified Team
# 111             Serbia and Montenegro
# 123                    Chinese Taipei
# 129               Trinidad and Tobago
# 135                     United States
# 140                    Virgin Islands
# 141                        Yugoslavia
# 142  Independent Olympic Participants
# 145                        Mixed team

# %% [markdown]
# ## 8

# %%
medals.loc[medals['country'].str.contains('Ger') | medals['country'].str.contains('Czech') |
          medals['country'].str.contains('Yugo') | medals['country'].str.contains('Britain') |
          medals['country'].str.contains('Russia') | medals['country'].str.contains('Soviet'), 'continent'] = 'EU'

# %%
medals.loc[medals.country.isin(['Australasia']), 'continent'] = 'OC'
medals.loc[medals.country.isin(['Canada', 'United States', 'Mexico']), 'continent'] = 'OC'
medals.loc[medals.country.isin(['Cuba', 'Jamaica']), 'continent'] = 'SA'

# %%
medals['continent'] = medals['continent'].fillna('OT')

# %% [markdown]
# ## 9

# %%
medals.set_index(['continent', 'country'], inplace=True)

# %% [markdown]
# ## 10

# %%
medals.sort_values(['continent', 'country'], ascending=[False, True], inplace=True)

# %% [markdown]
# ## 11

# %%
mul = pd.MultiIndex.from_tuples([('Summer', 'Game'), ('Summer', 'Gold'), ('Summer', 'Sliver'), ('Summer', 'Bronze'),
                                   ('Winter', 'Game'), ('Winter', 'Gold'), ('Winter', 'Sliver'), ('Winter', 'Bronze')])

# %%
old_col = medals.columns
medals.columns = mul
new_medals = medals.copy()
new_medals
# Out:
#                     Summer                    Winter
#                       Game Gold Sliver Bronze   Game Gold Sliver Bronze
# continent country
# SA        Argentina     23   18     24     28     18    0      0      0
#           Brazil        21   23     30     55      7    0      0      0
#           Chile         22    2      7      4     16    0      0      0
#           Colombia      18    2      6     11      1    0      0      0
#           Cuba          19   72     67     70      0    0      0      0
# ...                    ...  ...    ...    ...    ...  ...    ...    ...
# AF        Togo           9    0      0      1      1    0      0      0
#           Tunisia       13    3      3      4      0    0      0      0
#           Uganda        14    2      3      2      0    0      0      0
#           Zambia        12    0      1      1      0    0      0      0
#           Zimbabwe      12    3      4      1      1    0      0      0
#
# [146 rows x 8 columns]

# %% [markdown]
# ## 12

# %%
newer_medals = new_medals.stack(0).fillna(0)

# %%
newer_medals.index.names = ['Continent', 'Country', 'Season']

# %%
newer_medals
# Out:
#                             Bronze  Game  Gold  Sliver
# Continent Country   Season
# SA        Argentina Summer      28    23    18      24
#                     Winter       0    18     0       0
#           Brazil    Summer      55    21    23      30
#                     Winter       0     7     0       0
#           Chile     Summer       4    22     2       7
# ...                            ...   ...   ...     ...
# AF        Uganda    Winter       0     0     0       0
#           Zambia    Summer       1    12     0       1
#                     Winter       0     0     0       0
#           Zimbabwe  Summer       1    12     3       4
#                     Winter       0     1     0       0
#
# [292 rows x 4 columns]

# %% [markdown]
# ## 13

# %%
# newer_medals = newer_medals.reset_index().set_index(['Continent', 'Country', 'Season', 'Game'])

# %%
test = pd.melt(newer_medals.reset_index(),
               id_vars=['Continent', 'Country', 'Season', 'Game'],
               var_name='Medal',
               value_name='Count')

# %%
test.sort_values(by=['Continent', 'Country', 'Medal'])
# Out:
#     Continent    Country  Season  Game   Medal  Count
# 240        AF    Algeria  Summer    12  Bronze      8
# 241        AF    Algeria  Winter     3  Bronze      0
# 532        AF    Algeria  Summer    12    Gold      5
# 533        AF    Algeria  Winter     3    Gold      0
# 824        AF    Algeria  Summer    12  Sliver      2
# ..        ...        ...     ...   ...     ...    ...
# 25         SA  Venezuela  Winter     4  Bronze      0
# 316        SA  Venezuela  Summer    17    Gold      2
# 317        SA  Venezuela  Winter     4    Gold      0
# 608        SA  Venezuela  Summer    17  Sliver      2
# 609        SA  Venezuela  Winter     4  Sliver      0
#
# [876 rows x 6 columns]

# %%
test.loc[test.Country == 'Austria']
# Out:
#     Continent  Country  Season  Game   Medal  Count
# 88         EU  Austria  Summer    26  Bronze     35
# 89         EU  Austria  Winter    22  Bronze     81
# 380        EU  Austria  Summer    26    Gold     18
# 381        EU  Austria  Winter    22    Gold     59
# 672        EU  Austria  Summer    26  Sliver     33
# 673        EU  Austria  Winter    22  Sliver     78

# %% [markdown]
# ## 14

# %%
g_medals = test.loc[(test['Season'] == 'Summer') & (test['Medal'] == 'Gold')]

# %%
sort_g_medals = g_medals.groupby(g_medals.Continent, axis=0).sum()

# %%
sort_g_medals.reset_index(inplace=True)

# %%
sort_g_medals.sort_values(by=['Count'], ascending=False)
# Out:
#   Continent  Game  Count
# 2        EU   677   2731
# 4        OC   130   1232
# 1        AS   383    531
# 6        SA   224    141
# 0        AF   294    103
# 5        OT   142     60
# 3        NA   104     11

# %% [markdown]
# ## 15

# %%
test.groupby(test.Continent, axis=0).size()
# Out:
# Continent
# AF    156
# AS    180
# EU    282
# NA     48
# OC     42
# OT     90
# SA     78
# dtype: int64

# %% [markdown]
# ## 16

# %%
sum_g_medals = test.loc[(test['Season'] == 'Summer') & (test['Medal'] == 'Gold'), ['Continent', 'Country', 'Count']]

# %%
sum_g_medals.groupby(['Continent','Country']).sum()
# Out:
#                      Count
# Continent Country
# AF        Algeria        5
#           Botswana       0
#           Burundi        1
#           Cameroon       3
#           Djibouti       0
# ...                    ...
# SA        Paraguay       0
#           Peru           1
#           Suriname       1
#           Uruguay        2
#           Venezuela      2
#
# [146 rows x 1 columns]

# %% [markdown]
# ## 17

# %%
test.loc[:, ['Country', 'Season', 'Medal', 'Count']].groupby(['Season','Country','Medal']).sum()
# Out:
#                            Count
# Season Country     Medal
# Summer Afghanistan Bronze      2
#                    Gold        0
#                    Sliver      0
#        Algeria     Bronze      8
#                    Gold        5
# ...                          ...
# Winter Zambia      Gold        0
#                    Sliver      0
#        Zimbabwe    Bronze      0
#                    Gold        0
#                    Sliver      0
#
# [876 rows x 1 columns]

# %% [markdown]
# ## 18

# %%
g_medals.groupby(g_medals.Continent, axis=0).agg(AVG_Gold=('Count', 'mean'))
# Out:
#              AVG_Gold
# Continent
# AF           3.961538
# AS          17.700000
# EU          58.106383
# NA           1.375000
# OC         176.000000
# OT           4.000000
# SA          10.846154

# %% [markdown]
# ## 19

# %%
summer_oly = test.loc[(test['Game'] > 0) & (test['Season'] == 'Summer'), ['Continent', 'Country']]

# %%
summer_oly.drop_duplicates(inplace=True)

# %%
winter_oly = test.loc[(test['Game'] > 0) & (test['Season'] == 'Winter'), ['Continent', 'Country']]

# %%
winter_oly.drop_duplicates(inplace=True)

# %%
s = summer_oly.groupby('Continent').count()
w = winter_oly.groupby('Continent').count()

# %%
oly = pd.merge(s, w, left_on='Continent', right_on='Continent')

# %%
oly.columns = ['Summer', 'Winter']

# %%
oly
# Out:
#            Summer  Winter
# Continent
# AF             26      11
# AS             30      17
# EU             47      46
# NA              8       2
# OC              7       6
# OT             15      10
# SA             13       9

# %% [markdown]
# ## 20

# %%
all_g_medals.groupby(['Continent', 'Season']).agg(AVG_GOLD = ('Count','mean'))
# Out:
#                     AVG_GOLD
# Continent Season
# AF        Summer    3.961538
#           Winter    0.000000
# AS        Summer   17.700000
#           Winter    1.666667
# EU        Summer   58.106383
#           Winter   15.638298
# NA        Summer    1.375000
#           Winter    0.000000
# OC        Summer  176.000000
#           Winter   23.285714
# OT        Summer    4.000000
#           Winter    0.733333
# SA        Summer   10.846154
#           Winter    0.000000
